# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import time
import os
import scipy.stats as sts

# %%
data = pd.read_csv('glassdoordata.csv')
data.head()
# Out:
#                      Auris Health, Inc.  \
# 0  Applications Software Technology LLC
# 1                        Seen by Indeed
# 2                        Power Monitors
# 3                     Carnegie Robotics
# 4                        Ellation, Inc.
#
#                                      Program Manager Unnamed: 2  Unnamed: 3  \
# 0                   Associate Consultant- Technology     ANNUAL     76591.0
# 1                                    Project Manager        NaN         NaN
# 2                                     Sales Engineer     ANNUAL     71791.0
# 3                         Senior Mechanical Engineer     ANNUAL    162918.0
# 4  Sr. Product Manager, Community & Video Experience     ANNUAL    163692.0
#
#    Unnamed: 4  \
# 0     52158.0
# 1         NaN
# 2     47259.0
# 3     64786.0
# 4    113444.0
#
# ...
