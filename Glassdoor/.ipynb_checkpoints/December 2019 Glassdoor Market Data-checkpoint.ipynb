# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Read CSV 
data_df = pd.read_csv('glassdoordata.csv')

# %%
# Rename Columns & Organize
renamed_data_df = data_df.rename(columns={"Company Name Witheld":"Company", "Low Salry":"Low Salary", "Job Description":"job_description", "Job Title":"job_title"})
industry_df = renamed_data_df.set_index('Industry')
industry_cat_df = industry_df.rename(index={"Accounting":"Business/Finance/Accounting", "Advertising & Marketing" : "Business/Finance/Accounting", "Banks & Building Societies":"Business/Finance/Accounting", "Insurance Agencies & Brokerages":"Business/Finance/Accounting","Insurance Operators":"Business/Finance/Accounting","Investment Banking & Asset Management":"Business/Finance/Accounting","Lending":"Business/Finance/Accounting",
                          "Computer Hardware & Software":"Computer/Internet", "Enterprise Software & Network Solutions":"Computer/Internet", "IT Services":"Computer/Internet","Internet":"Computer/Internet", "Research & Development":"Computer/Internet","Enterprise Software & Network Solutions":"Computer/Internet", 
                          "Consulting" : "Consulting/Recruiting", "Staffing & Outsourcing" :"Consulting/Recruiting",   
                          "Charitable Foundations" : "Education", "Colleges & Universities": "Education", "Religious Organisations":"Education",
                          "Areospace & Defense": "Government/Military", "Government Agencies": "Government/Military",
                          "Biotech & Pharmaceuticals": "Healthcare","Healthcare Services & Hospitals": "Healthcare",
                          "Estate Agents":"Sales/HR/Retail/Services","General Merchandise & Superstores":"Sales/HR/Retail/Services","Legal":"Sales/HR/Retail/Services","Publishing":"Sales/HR/Retail/Services","Telecommunications Services":"Sales/HR/Retail/Services","Utilities":"Sales/HR/Retail/Services","Video Games":"Sales/HR/Retail/Services","holesale":"Sales/HR/Retail/Services","Brokerage Services":"Sales/HR/Retail/Services","Catering & Food Service Contractors":"Sales/HR/Retail/Services", 
                          "Membership Organisations":"Life/Physical/Social Sciences",
                          "Asphalt Product Manufacturing":"Manufacturing/Mechanical/Construction","Chemical Manufacturing":"Manufacturing/Mechanical/Construction", "Consumer Products Manufacturing":"Manufacturing/Mechanical/Construction","Industrial Manufacturing":"Manufacturing/Mechanical/Construction"})

industry_cat_df.head(50)
# Out:
#                                                                       Company  \
# Industry
# Healthcare Product Manufacturing                           Auris Health, Inc.
# Computer/Internet                        Applications Software Technology LLC
# NaN                                                            Seen by Indeed
# Electrical & Electronic Manufacturing                          Power Monitors
# Electrical & Electronic Manufacturing                       Carnegie Robotics
# Computer/Internet                                              Ellation, Inc.
# Computer/Internet                                                    Kite.com
# Sales/HR/Retail/Services                                    TracFone Wireless
# Travel Agencies                                               Fareportal Inc.
# NaN                                                      Hunter International
# Building & Construction                                      Corbins Electric
# Computer/Internet                                                   Glassdoor
# Business/Finance/Accounting                       North American Savings Bank
# Business/Finance/Accounting                                         Metromile
# Electrical & Electronic Manufacturing                       Applied Materials
# NaN                                                             Excello Homes
# Logistics & Supply Chain                                 Tideworks Technology
# Healthcare                                                              ADURO
# Business/Finance/Accounting                                    Octane Lending
# NaN                                                      Access Systems, Inc.
# NaN                                    HireResources - Information Technology
# Healthcare                                                  SAGE Therapeutics
# Computer/Internet                                                   Stefanini
# Consulting/Recruiting                          Source One Technical Solutions
# Consulting/Recruiting                                              Net2Source
# Computer/Internet                                           Stride Consulting
# Business/Finance/Accounting                                         Metromile
# Computer/Internet                                               Torc Robotics
# Computer/Internet                                                     vXchnge
# NaN                                             Boston Lighthouse Innovations
# NaN                                                         WB Games New York
# Computer/Internet                                                         IBM
# Computer/Internet                                        Procore Technologies
# Computer/Internet                           Business Technology Partners, LLP
# NaN                                                                Akinnovate
# Education Training Services                                        Codecademy
# Computer/Internet                                                       Avvio
# Consulting/Recruiting                                Software Resources, Inc.
# Computer/Internet                                                  EverString
# Aerospace & Defence                                                      KeyW
# Computer/Internet                                                 KeepTruckin
# Business/Finance/Accounting                          Liberty Mutual Insurance
# Building & Construction                                               Graycor
# Computer/Internet                                        Clean Power Research
# Computer/Internet                                                      Ibotta
# Computer/Internet                                                      Apolis
# Healthcare                                                   Reaction Biology
# Aerospace & Defence                                        CACI International
# Computer/Internet                                                   Glassdoor
# Computer/Internet                                                    Kite.com
#
#                                                                                job_title  \
# Industry
# Healthcare Product Manufacturing                                         Program Manager
# Computer/Internet                                       Associate Consultant- Technology
# NaN                                                                      Project Manager
# Electrical & Electronic Manufacturing                                     Sales Engineer
# Electrical & Electronic Manufacturing                         Senior Mechanical Engineer
# Computer/Internet                      Sr. Product Manager, Community & Video Experience
# Computer/Internet                                              Machine Learning Engineer
# Sales/HR/Retail/Services                                 Sr. Analyst, Product Operations
# Travel Agencies                                            Business Intelligence Analyst
# NaN                                                                         Statistician
# Building & Construction                                     Project Manager (New Mexico)
# Computer/Internet                                Senior Product Manager, Jobs Experience
# Business/Finance/Accounting                                                 Data Analyst
# Business/Finance/Accounting                                         Supply Chain Manager
# Electrical & Electronic Manufacturing                                       Statistician
# NaN                                    Project Manager- Residential Construction- Sin...
# Logistics & Supply Chain                                 Senior Business Systems Analyst
# Healthcare                                                                  Data Analyst
# Business/Finance/Accounting                                         Senior Data Engineer
# NaN                                                 Senior Network Technology Consultant
# NaN                                                                       Data Scientist
# Healthcare                                                       Director, Biostatistics
# Computer/Internet                                                           Data Analyst
# Consulting/Recruiting                                                       Data Analyst
# Consulting/Recruiting                                                    Statistician II
# Computer/Internet                                   Lead Software Development Consultant
# Business/Finance/Accounting                                       Senior Product Manager
# Computer/Internet                                                       Network Engineer
# Computer/Internet                      Product Manager; Business Continuity/Disaster ...
# NaN                                         Cloud Software Engineer - Precision Medicine
# NaN                                                               Senior DevOps Engineer
# Computer/Internet                                                     Research Scientist
# Computer/Internet                                 Director of Engineer, Data & Analytics
# Computer/Internet                                             Intacct Senior Consultants
# NaN                                                                         Data Analyst
# Education Training Services             Senior Backend Engineer: Learner Experience Team
# Computer/Internet                                                        Account Manager
# Consulting/Recruiting                                               Testing/Data Analyst
# Computer/Internet                                                Senior Backend Engineer
# Aerospace & Defence                                                       Data Scientist
# Computer/Internet                                      Senior Embedded Software Engineer
# Business/Finance/Accounting            Business Analyst II /Senior Business Analyst -...
# Building & Construction                                     Construction Project Manager
# Computer/Internet                                                      Software Engineer
# Computer/Internet                                    Principal Machine Learning Engineer
# Computer/Internet                                                         Data Scientist
# Healthcare                                              Research Associate, Cell Biology
# Aerospace & Defence                                                       Data Scientist
# Computer/Internet                                        Lead Machine Learning Scientist
# Computer/Internet                                              Machine Learning Engineer
#
#                                       Pay Type  High Salary  Low Salary  \
# Industry
# Healthcare Product Manufacturing           NaN          NaN         NaN
# Computer/Internet                       ANNUAL      76591.0     52158.0
# NaN                                        NaN          NaN         NaN
# Electrical & Electronic Manufacturing   ANNUAL      71791.0     47259.0
# Electrical & Electronic Manufacturing   ANNUAL     162918.0     64786.0
# Computer/Internet                       ANNUAL     163692.0    113444.0
# Computer/Internet                          NaN          NaN         NaN
# Sales/HR/Retail/Services                ANNUAL     111171.0     68753.0
# Travel Agencies                         ANNUAL      77022.0     54645.0
# NaN                                     ANNUAL      79627.0     51594.0
# Building & Construction                 ANNUAL     100982.0     66943.0
# Computer/Internet                       ANNUAL     180598.0    124519.0
# Business/Finance/Accounting             ANNUAL      76361.0     48957.0
# Business/Finance/Accounting             ANNUAL     100128.0     62258.0
# Electrical & Electronic Manufacturing   ANNUAL     145834.0     97898.0
# NaN                                        NaN          NaN         NaN
# Logistics & Supply Chain                ANNUAL     119763.0     77716.0
# Healthcare                              ANNUAL      79363.0     52900.0
# Business/Finance/Accounting                NaN          NaN         NaN
# NaN                                        NaN          NaN         NaN
# NaN                                        NaN          NaN         NaN
# Healthcare                              ANNUAL     285934.0    226575.0
# Computer/Internet                       ANNUAL      68589.0     40217.0
# Consulting/Recruiting                      NaN          NaN         NaN
# Consulting/Recruiting                      NaN          NaN         NaN
# Computer/Internet                       ANNUAL     191878.0    128302.0
# Business/Finance/Accounting             ANNUAL     194083.0    133943.0
# Computer/Internet                       ANNUAL      86557.0     53878.0
# Computer/Internet                       ANNUAL     125311.0     84526.0
# NaN                                        NaN          NaN         NaN
# NaN                                        NaN          NaN         NaN
# Computer/Internet                          NaN          NaN         NaN
# Computer/Internet                       ANNUAL     165240.0    119705.0
# Computer/Internet                       ANNUAL      93165.0     55270.0
# NaN                                        NaN          NaN         NaN
# Education Training Services             ANNUAL     169601.0    133018.0
# Computer/Internet                          NaN          NaN         NaN
# Consulting/Recruiting                   ANNUAL      82729.0     48090.0
# Computer/Internet                       ANNUAL     229642.0    182344.0
# Aerospace & Defence                     ANNUAL     162779.0    117863.0
# Computer/Internet                       ANNUAL     111275.0     67738.0
# Business/Finance/Accounting             ANNUAL     112907.0     77324.0
# Building & Construction                 ANNUAL     131237.0     84266.0
# Computer/Internet                          NaN          NaN         NaN
# Computer/Internet                          NaN          NaN         NaN
# Computer/Internet                       ANNUAL     128654.0     92728.0
# Healthcare                              ANNUAL      44761.0     33378.0
# Aerospace & Defence                     ANNUAL     160540.0    113382.0
# Computer/Internet                       ANNUAL     181857.0    135408.0
# Computer/Internet                          NaN          NaN         NaN
#
#                                                                          job_description  \
# Industry
# Healthcare Product Manufacturing       <strong>Overview:</strong>\n<br/><br/>\nAs the...
# Computer/Internet                      <strong>Have a Technology Background?\n<br/>\n...
# NaN                                    <div><div><div><strong>Seen by Indeed is a fre...
# Electrical & Electronic Manufacturing  <p>Power Monitors, Inc. is seeking a Sales Eng...
# Electrical & Electronic Manufacturing  <p><strong>Role:</strong> Senior Mechanical En...
# Computer/Internet                      <div>\n<div>\n<div>\n<div><strong>Crunchyroll<...
# Computer/Internet                      Programmers spend too much time doing repetiti...
# Sales/HR/Retail/Services               TracFone is seeking an individual who will man...
# Travel Agencies                        <strong>(We are not sponsoring for this role n...
# NaN                                    <h3>Job Description</h3><div><div><strong>Stat...
# Building & Construction                <p>At Corbins Electric, we believe people are ...
# Computer/Internet                      Glassdoor's mission is to help people everywhe...
# Business/Finance/Accounting            <h3>Job Description</h3><div>North American Sa...
# Business/Finance/Accounting            <strong>About us</strong>\n<br/><br/>\nOn the ...
# Electrical & Electronic Manufacturing  <h3>Job Description</h3><div>Applied Materials...
# NaN                                    <b>Single -Family Residential Construction Pro...
# Logistics & Supply Chain               <div><strong>Summary/Objective:</strong> The <...
# Healthcare                             <strong><div>SUMMARY</strong>:</div>\n\n<br/><...
# Business/Finance/Accounting            The $21B Powersports market (motorcycles, ATVs...
# NaN                                    A Senior Network Technology Consultant is a ch...
# NaN                                    <h3>Job Description</h3><div>We are seeking a ...
# Healthcare                             <strong><strong>General Scope and Summary</str...
# Computer/Internet                      <div><strong>Stefanini is looking for a Data A...
# Consulting/Recruiting                  Data Analyst\n<br/><br/>\n<strong>Job Descript...
# Consulting/Recruiting                  <strong>======================================...
# Computer/Internet                      <strong>Join our Family</strong>\n<br/><br/>\n...
# Business/Finance/Accounting            <strong>About us</strong>\n<br/><br/>\nOn the ...
# Computer/Internet                      We are seeking people who are passionate about...
# Computer/Internet                      <br>\r\n<p>We are recognized by top industry a...
# NaN                                    <p><strong>OVERVIEW:</strong></p>\r\n<p>Boston...
# NaN                                    <p><strong>Senior DevOps Engineer (Needham, MA...
# Computer/Internet                      Introduction\n<br/>\nIBM Research Scientists a...
# Computer/Internet                      Procore's global platform is revolutionizing t...
# Computer/Internet                      <p>Looking for a new challenge in a flexible e...
# NaN                                    <h3>Job Description</h3><div><strong>Responsib...
# Education Training Services            <div>Hello, World! Codecademy has helped over ...
# Computer/Internet                      At Avvio, we are looking for people who are ea...
# Consulting/Recruiting                  <strong>Software Resources has an immeidate, c...
# Computer/Internet                      <strong>Description</strong>\n<br/><br/>\nEver...
# Aerospace & Defence                    <p>Be part of an exciting team dedicated to ke...
# Computer/Internet                      <h3><strong>Who we are:</strong></h3><br/><br/...
# Business/Finance/Accounting            <div><div><strong>Advance your career at Liber...
# Building & Construction                <strong>As a Project Manager with Graycor Cons...
# Computer/Internet                      <p><strong>WHO ARE WE?</strong></p>\r\n<p>Look...
# Computer/Internet                      Ibotta is seeking a <strong>Principal Machine ...
# Computer/Internet                      Data Scientist Architect\n<br/><br/>\nIrvine C...
# Healthcare                             <p>Reaction Biology Corp (RBC), a Malvern PA -...
# Aerospace & Defence                    <p><strong>Job Description</strong></p><p></p>...
# Computer/Internet                      <strong>The Role</strong>\n<br/><br/>\nYou'll ...
# Computer/Internet                      Programmers spend too much time doing repetiti...
#
#                                       Country           City, State  \
# Industry
# Healthcare Product Manufacturing           US      Redwood City, CA
# Computer/Internet                          US             Lisle, IL
# NaN                                        US     San Francisco, CA
# Electrical & Electronic Manufacturing      US    Mount Crawford, VA
# Electrical & Electronic Manufacturing      US        Pittsburgh, PA
# Computer/Internet                          US     San Francisco, CA
# Computer/Internet                          US     San Francisco, CA
# Sales/HR/Retail/Services                   US             Miami, FL
# Travel Agencies                            US          New York, NY
# NaN                                        US      Chesterfield, MO
# Building & Construction                    US       Albuquerque, NM
# Computer/Internet                          US     San Francisco, CA
# Business/Finance/Accounting                US       Kansas City, MO
# Business/Finance/Accounting                US             Tempe, AZ
# Electrical & Electronic Manufacturing      US       Santa Clara, CA
# NaN                                        US           Houston, TX
# Logistics & Supply Chain                   US           Seattle, WA
# Healthcare                                 US           Redmond, WA
# Business/Finance/Accounting                US          New York, NY
# NaN                                        US         Knoxville, TN
# NaN                                        US          Richmond, VA
# Healthcare                                 US         Cambridge, MA
# Computer/Internet                          US           Reading, PA
# Consulting/Recruiting                      US        Hicksville, NY
# Consulting/Recruiting                      US           Madison, NJ
# Computer/Internet                          US          New York, NY
# Business/Finance/Accounting                US     San Francisco, CA
# Computer/Internet                          US        Blacksburg, VA
# Computer/Internet                          US             Tampa, FL
# NaN                                        US         Cambridge, MA
# NaN                                        US   Needham Heights, MA
# Computer/Internet                          US           Lansing, MI
# Computer/Internet                          US            Austin, TX
# Computer/Internet                          US         Milwaukee, WI
# NaN                                        US        Washington, DC
# Education Training Services                US          New York, NY
# Computer/Internet                          US             Miami, FL
# Consulting/Recruiting                      US           Orlando, FL
# Computer/Internet                          US         San Mateo, CA
# Aerospace & Defence                        US           Herndon, VA
# Computer/Internet                          US           Buffalo, NY
# Business/Finance/Accounting                US          New York, NY
# Building & Construction                    US  Oakbrook Terrace, IL
# Computer/Internet                          US          Kirkland, WA
# Computer/Internet                          US            Denver, CO
# Computer/Internet                          US            Irvine, CA
# Healthcare                                 US           Malvern, PA
# Aerospace & Defence                        US         Chantilly, VA
# Computer/Internet                          US     San Francisco, CA
# Computer/Internet                          US     San Francisco, CA
#
#                                        Rating Average  Number of Ratings
# Industry
# Healthcare Product Manufacturing                 0.75               2812
# Computer/Internet                                0.99               2850
# NaN                                               NaN               2869
# Electrical & Electronic Manufacturing            0.31               2875
# Electrical & Electronic Manufacturing            1.00               2931
# Computer/Internet                                0.43               3008
# Computer/Internet                                1.00               3022
# Sales/HR/Retail/Services                         0.27               3050
# Travel Agencies                                  0.69               8476
# NaN                                              0.93              14020
# Building & Construction                          0.81              14121
# Computer/Internet                                0.80              14123
# Business/Finance/Accounting                      0.88              14139
# Business/Finance/Accounting                      0.89              14189
# Electrical & Electronic Manufacturing            0.68              14250
# NaN                                             -0.10              14302
# Logistics & Supply Chain                         0.91              19667
# Healthcare                                       0.67              19719
# Business/Finance/Accounting                      1.00              19829
# NaN                                               NaN              19848
# NaN                                              1.00              34888
# Healthcare                                       0.96              34906
# Computer/Internet                                0.71              35072
# Consulting/Recruiting                            1.00              35180
# Consulting/Recruiting                            0.43              46143
# Computer/Internet                                0.90              46196
# Business/Finance/Accounting                      0.89              46339
# Computer/Internet                                0.80              46807
# Computer/Internet                                0.82              46825
# NaN                                               NaN              46903
# NaN                                               NaN              46910
# Computer/Internet                                0.72              47056
# Computer/Internet                                0.79              47079
# Computer/Internet                                1.00              47106
# NaN                                              1.00              47154
# Education Training Services                      0.48              98077
# Computer/Internet                                0.86              98192
# Consulting/Recruiting                            1.00              98720
# Computer/Internet                                0.73               3755
# Aerospace & Defence                              0.73               3781
# Computer/Internet                                0.92               3792
# Business/Finance/Accounting                      0.55               3838
# Building & Construction                          0.63               3886
# Computer/Internet                                0.90               3953
# Computer/Internet                                0.73               9516
# Computer/Internet                                0.90              14893
# Healthcare                                       0.65              15036
# Aerospace & Defence                              0.65              20450
# Computer/Internet                                0.80              20514
# Computer/Internet                                1.00              20515

# %%
# find data positions and concat
data_analyst_df = industry_cat_df[(industry_cat_df['job_title'] == "Data Analyst")]
data_engineer_df = industry_cat_df[(industry_cat_df['job_title'] == "Data Engineer")]
data_scientist_df = industry_cat_df[(industry_cat_df['job_title'] == "Data Scientist")]
data_jobs_df = pd.concat([data_analyst_df,data_engineer_df,data_scientist_df], ignore_index=False)
data_jobs_df.head()
# Out:
#                                                     Company     job_title  \
# Industry
# Business/Finance/Accounting     North American Savings Bank  Data Analyst
# Healthcare                                            ADURO  Data Analyst
# Computer/Internet                                 Stefanini  Data Analyst
# Consulting/Recruiting        Source One Technical Solutions  Data Analyst
# NaN                                              Akinnovate  Data Analyst
#
#                             Pay Type  High Salary  Low Salary  \
# Industry
# Business/Finance/Accounting   ANNUAL      76361.0     48957.0
# Healthcare                    ANNUAL      79363.0     52900.0
# Computer/Internet             ANNUAL      68589.0     40217.0
# Consulting/Recruiting            NaN          NaN         NaN
# NaN                              NaN          NaN         NaN
#
#                                                                job_description  \
# Industry
# Business/Finance/Accounting  <h3>Job Description</h3><div>North American Sa...
# Healthcare                   <strong><div>SUMMARY</strong>:</div>\n\n<br/><...
# Computer/Internet            <div><strong>Stefanini is looking for a Data A...
# Consulting/Recruiting        Data Analyst\n<br/><br/>\n<strong>Job Descript...
# NaN                          <h3>Job Description</h3><div><strong>Responsib...
#
#                             Country      City, State  Rating Average  \
# Industry
# Business/Finance/Accounting      US  Kansas City, MO            0.88
# Healthcare                       US      Redmond, WA            0.67
# Computer/Internet                US      Reading, PA            0.71
# Consulting/Recruiting            US   Hicksville, NY            1.00
# NaN                              US   Washington, DC            1.00
#
#                              Number of Ratings
# Industry
# Business/Finance/Accounting              14139
# Healthcare                               19719
# Computer/Internet                        35072
# Consulting/Recruiting                    35180
# NaN                                      47154

# %%
positions = ['Data Analyst','Data Engineer','Data Scientist',]
        
            
value = [79824,126466,129664,]
plt.barh(positions, value, color='b', alpha=0.5, align="center")

plt.title("Average Salary by Title")
plt.xlabel("Average Salary")

plt.grid()
plt.show()
plt.savefig("Bar_Salary_vs_Title.png")
plt.tight_layout()

# %%
positions = ['Data Engineer','Data Scientist','Data Analyst']
        
            
value = [126446,164,255]
plt.barh(positions, value, color='b', alpha=0.5, align="center")

plt.title("Job Openings for Job Title")
plt.xlabel("Number of Positions")

plt.grid()
plt.show()
plt.savefig("Bar_Job_Openings_vs_Title.png")
plt.tight_layout()

# %%
# do a pie chart of the number of job openings for different levels
topic =  ["Data Engineer", "Data Scientist", "Data Analyst"]

# Labels for the sections of our pie chart
labels = list(topic)
# The values of each section of the pie chart
sizes = [33, 164, 255]

# The colors of each section of the pie chart
colors = ["orange", "lightblue", "lightgreen"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0, 0, 0.1)

plt.figure(figsize=(9,9))

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%2.f%%", startangle=140)

plt.axis("equal")
plt.title('Job Title Distribution')
plt.savefig("Job_Title_Distribution.png")
plt.show()

# %%
# create new columns with above keywords to store the flag,
# indicating if that specific keyword is included in the description
# 0 -> not included; 
# 1 -> includeddata_jobs_df['JS_part_flag'] = 0 
data_jobs_df['TS_part_flag'] = 0
data_jobs_df['TS_full_flag'] = 0 
data_jobs_df['TS_intern_flag'] = 0 
data_jobs_df['TS_contract_flag'] = 0 
data_jobs_df.head(1)
# Out:
#                                                  Company     job_title  \
# Industry
# Business/Finance/Accounting  North American Savings Bank  Data Analyst
#
#                             Pay Type  High Salary  Low Salary  \
# Industry
# Business/Finance/Accounting   ANNUAL      76361.0     48957.0
#
#                                                                job_description  \
# Industry
# Business/Finance/Accounting  <h3>Job Description</h3><div>North American Sa...
#
#                             Country      City, State  Rating Average  \
# Industry
# Business/Finance/Accounting      US  Kansas City, MO            0.88
#
#                              Number of Ratings  TS_part_flag  TS_full_flag  \
# Industry
# Business/Finance/Accounting              14139             0             0
#
#                              TS_intern_flag  TS_contract_flag
# Industry
# Business/Finance/Accounting               0                 0

# %%
for irow in np.arange(len(data_jobs_df)):
       
    if (("part-time" in data_jobs_df.job_description[irow]) or ("part time" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,10] = 1
        
    if (("full-time" in data_jobs_df.job_description[irow]) or ("full time" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,11] = 1
       
    if ("internship" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,12] = 1
    
    if ("contractor" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,13] = 1

JS_keywords = ['Part Time', 'Full Time', 'Internship', 'Contractor']
JS_Count = np.arange(len(JS_keywords))

for i_tech_skill in np.arange(len(JS_keywords)):
    
    JS_Count[i_tech_skill] = data_jobs_df.iloc[:,10+i_tech_skill].sum()

JS_Count
# Out:
# array([ 0, 29,  0,  7])

# %%
df_JS = pd.DataFrame({'JS_keywords':JS_keywords, 'JSkeywords_Counts':JS_Count})
df_JS.sort_values('JSkeywords_Counts',inplace=True)

plt.figure(figsize=(13,8))
fig,ax = plt.subplots()

ax.barh(df_JS.JS_keywords, df_JS.JSkeywords_Counts, color='b', alpha=0.5, align="center")

plt.title("Job Types by Open Positions")
ax.set_xlabel("Number of Job Openings")

for i, v in enumerate(df_JS.JSkeywords_Counts):
    ax.text(v + 30, i, str(v), color='black', fontweight='bold')
plt.grid()

plt.tight_layout()
plt.savefig("Job_type_vs_Openings.png")
plt.show()

# %%
grouped_cat = data_jobs_df.groupby('Industry')['job_title'].count().sort_values(ascending=False)
grouped_cat.head(50)
# Out:
# Industry
# Computer/Internet                        131
# Consulting/Recruiting                    101
# Business/Finance/Accounting               44
# Sales/HR/Retail/Services                  27
# Healthcare                                18
# Education                                  9
# Aerospace & Defence                        9
# Manufacturing/Mechanical/Construction      8
# Government/Military                        3
# Film Production & Distribution             3
# Sports & Recreation                        3
# Music Production & Distribution            2
# Life/Physical/Social Sciences              2
# Haulage                                    2
# Home Furniture and Houseware Shops         1
# Transportation Management                  1
# Financial Transaction Processing           1
# News Outlets                               1
# Department, Clothing, & Shoe Shops         1
# Security Services                          1
# Sporting Goods Shops                       1
# Wholesale                                  1
# Name: job_title, dtype: int64

# %%
# Bar Chart, Position by industry
positions = ['Life/Physical/Social Sciences','Government/Military','Manufacturing/Mechanical/Construction','Areospace & Defence','Education','Healthcare','Sales/HR/Retail/Services','Business/Finance/Accounting','Consultcing/Recruiting','Computer/Internet']
        
            
value = [2,3,8,9,9,18,27,44,101,131]
plt.barh(positions, value, color='b', alpha=0.5, align="center")

plt.title("Job Openings for Industry Sector")
plt.xlabel("Total Avaiable Positions")
plt.ylabel("Industry of Availble Data Position")

plt.grid()
plt.show()
plt.savefig("Bar_Job_Openings_vs_Industry.png")
plt.tight_layout()

# %%
# --------- 1) Technical Skills ------------

# finalized technical skill set keywords:

# Statistics / Statistical Analysis
# Research / Research Design
# Question Formulation 
# Visualization
# Deep Learning
# Machine Learning
# Domain Knowledge
# Analysis / Analytical
# Cloud Computing (AWS)
# Regression
# Probability
# Prediction
# Network / Neural Networks

# create new columns with above keywords to store the flag,
# indicating if that specific keyword is included in the description
# 0 -> not included; 
# 1 -> included

# initialize the flag tags
data_jobs_df['TS_Stats_flag'] = 0 
data_jobs_df['TS_Research_flag'] = 0 
data_jobs_df['TS_QuesForm_flag'] = 0 
data_jobs_df['TS_Visual_flag'] = 0 
data_jobs_df['TS_DeepLearning_flag'] = 0 
data_jobs_df['TS_MachineLearning_flag'] = 0 
data_jobs_df['TS_DomainKnowledge_flag'] = 0 
data_jobs_df['TS_Analy_flag'] = 0 
data_jobs_df['TS_CloudComp_flag'] = 0 
data_jobs_df['TS_Regress_flag'] = 0 
data_jobs_df['TS_Probability_flag'] = 0 
data_jobs_df['TS_Prediction_flag'] = 0 
data_jobs_df['TS_NeuralNetwork_flag'] = 0 
data_jobs_df.head(5)
# Out:
#                                                     Company     job_title  \
# Industry
# Business/Finance/Accounting     North American Savings Bank  Data Analyst
# Healthcare                                            ADURO  Data Analyst
# Computer/Internet                                 Stefanini  Data Analyst
# Consulting/Recruiting        Source One Technical Solutions  Data Analyst
# NaN                                              Akinnovate  Data Analyst
#
#                             Pay Type  High Salary  Low Salary  \
# Industry
# Business/Finance/Accounting   ANNUAL      76361.0     48957.0
# Healthcare                    ANNUAL      79363.0     52900.0
# Computer/Internet             ANNUAL      68589.0     40217.0
# Consulting/Recruiting            NaN          NaN         NaN
# NaN                              NaN          NaN         NaN
#
#                                                                job_description  \
# Industry
# Business/Finance/Accounting  <h3>Job Description</h3><div>North American Sa...
# Healthcare                   <strong><div>SUMMARY</strong>:</div>\n\n<br/><...
# Computer/Internet            <div><strong>Stefanini is looking for a Data A...
# Consulting/Recruiting        Data Analyst\n<br/><br/>\n<strong>Job Descript...
# NaN                          <h3>Job Description</h3><div><strong>Responsib...
#
#                             Country      City, State  Rating Average  \
# Industry
# Business/Finance/Accounting      US  Kansas City, MO            0.88
# Healthcare                       US      Redmond, WA            0.67
# Computer/Internet                US      Reading, PA            0.71
# Consulting/Recruiting            US   Hicksville, NY            1.00
# NaN                              US   Washington, DC            1.00
#
#                              Number of Ratings  ...  TS_Visual_flag  \
# Industry                                        ...
# Business/Finance/Accounting              14139  ...               0
# Healthcare                               19719  ...               0
# Computer/Internet                        35072  ...               0
# Consulting/Recruiting                    35180  ...               0
# NaN                                      47154  ...               0
#
#                              TS_DeepLearning_flag  TS_MachineLearning_flag  \
# Industry
# Business/Finance/Accounting                     0                        0
# Healthcare                                      0                        0
# Computer/Internet                               0                        0
# Consulting/Recruiting                           0                        0
# NaN                                             0                        0
#
#                              TS_DomainKnowledge_flag  TS_Analy_flag  \
# Industry
# Business/Finance/Accounting                        0              0
# Healthcare                                         0              0
# Computer/Internet                                  0              0
# Consulting/Recruiting                              0              0
# NaN                                                0              0
#
#                              TS_CloudComp_flag  TS_Regress_flag  \
# Industry
# Business/Finance/Accounting                  0                0
# Healthcare                                   0                0
# Computer/Internet                            0                0
# Consulting/Recruiting                        0                0
# NaN                                          0                0
#
#                              TS_Probability_flag  TS_Prediction_flag  \
# Industry
# Business/Finance/Accounting                    0                   0
# Healthcare                                     0                   0
# Computer/Internet                              0                   0
# Consulting/Recruiting                          0                   0
# NaN                                            0                   0
#
#                              TS_NeuralNetwork_flag
# Industry
# Business/Finance/Accounting                      0
# Healthcare                                       0
# Computer/Internet                                0
# Consulting/Recruiting                            0
# NaN                                              0
#
# [5 rows x 27 columns]

# %%
for irow in np.arange(len(data_jobs_df)):
    
    if ("statist" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,10] = 1
    
    if (("reasearch" in data_jobs_df.job_description[irow]) or ("research design" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,11] = 1
        
    if ("question formulation" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,12] = 1
        
    if ("visual" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,13] = 1
    
    if ("deep learning" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,14] = 1  
    
    if (("machine learning" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,15] = 1
    
    if (("domain knowledge" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,16] = 1
    
    if (("analy" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,17] = 1
    
    if (("cloud comp" in data_jobs_df.job_description[irow]) or ("contractor" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,18] = 1
        
    if (("regres" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,19] = 1
    
    if (("probabil" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,20] = 1
    
    if (("prediction" in data_jobs_df.job_description[irow]) or ("forecast" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,21] = 1
    
    if (("neural network" in data_jobs_df.job_description[irow]) ):
        data_jobs_df.iloc[irow,22] = 1

TS_keywords = ['Statistics', 'Research', 'Question Formulation', 'Visualization',\
               'Deep Learning','Machine Learning','Domain Knowledge', 'Analytical',\
               'Cloud Computing', 'Regression', 'Probability', 'Prediction','Neural Networks']
TS_Count = np.arange(len(TS_keywords))

for i_tech_skill in np.arange(len(TS_keywords)):
    
    TS_Count[i_tech_skill] = data_jobs_df.iloc[:,10+i_tech_skill].sum()

TS_Count
# Out:
# array([219,  31,   0, 152,  19, 105,   3, 391,  17,  43,  12,  45,  13])

# %%
# construct a dataFrame using the TS keywords and TS keyword counts
df_TS = pd.DataFrame({'TS_Keywords':TS_keywords, 'TSkeywords_Counts':TS_Count})
df_TS.sort_values('TSkeywords_Counts',inplace=True)

# now do a bar chart on desired Technical Skills
plt.figure(figsize=(13,8))
fig,ax = plt.subplots()

ax.barh(df_TS.TS_Keywords, df_TS.TSkeywords_Counts, color='b', alpha=0.5, align="center")

plt.title("Popularity of Desired Technical Skills")
ax.set_xlabel("Number of Job Openings Requiring the Technical Skill")

for i, v in enumerate(df_TS.TSkeywords_Counts):
    ax.text(v + 30, i, str(v), color='black', fontweight='bold')
plt.grid()

plt.tight_layout()
plt.savefig("Bar_Popularity_of_Desired_Technical_Skills.png", bbox_inches='tight')
plt.show()

# %%
# Keywords for soft skill sets:

# Communication
# Teamwork
# Question formulation
# Storytelling
# Project management

# initialize the flag tags
data_jobs_df['SS_Communication_flag'] = 0 
data_jobs_df['SS_Teamwork_flag'] = 0 
data_jobs_df['SS_QuesForm_flag'] = 0 
data_jobs_df['SS_StoryTelling_flag'] = 0 
data_jobs_df['SS_ProjManagement_flag'] = 0 

data_jobs_df.head(1)
# Out:
#                                                  Company     job_title  \
# Industry
# Business/Finance/Accounting  North American Savings Bank  Data Analyst
#
#                             Pay Type  High Salary  Low Salary  \
# Industry
# Business/Finance/Accounting   ANNUAL      76361.0     48957.0
#
#                                                                job_description  \
# Industry
# Business/Finance/Accounting  <h3>Job Description</h3><div>North American Sa...
#
#                             Country      City, State  Rating Average  \
# Industry
# Business/Finance/Accounting      US  Kansas City, MO            0.88
#
#                              Number of Ratings  ...  TS_CloudComp_flag  \
# Industry                                        ...
# Business/Finance/Accounting              14139  ...                  0
#
#                              TS_Regress_flag  TS_Probability_flag  \
# Industry
# Business/Finance/Accounting                0                    0
#
#                              TS_Prediction_flag  TS_NeuralNetwork_flag  \
# Industry
# Business/Finance/Accounting                   0                      0
#
#                              SS_Communication_flag  SS_Teamwork_flag  \
# Industry
# Business/Finance/Accounting                      0                 0
#
#                              SS_QuesForm_flag  SS_StoryTelling_flag  \
# Industry
# Business/Finance/Accounting                 0                     0
#
#                              SS_ProjManagement_flag
# Industry
# Business/Finance/Accounting                       0
#
# [1 rows x 32 columns]

# %%
for irow in np.arange(len(data_jobs_df)):
    
    if (("communica" in data_jobs_df.job_description[irow]) or ("personal skill" in data_jobs_df.job_description[irow])\
       or ("people skill" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,23] = 1
    
    if (("teamwork" in data_jobs_df.job_description[irow]) or ("team work" in data_jobs_df.job_description[irow])\
          or ("team player" in data_jobs_df.job_description[irow]) or ("collabor" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,24] = 1
        
    if ("question formulation" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,25] = 1
        
    if (("story telling" in data_jobs_df.job_description[irow]) or ("storytelling" in data_jobs_df.job_description[irow])):
        data_jobs_df.iloc[irow,26] = 1
    
    if ("project management" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,27] = 1  
    
SS_keywords = ['Communication', 'Teamwork', 'Question_Formulation', 'Story_Telling','Project_Management']
SS_Count = np.arange(len(SS_keywords))

for i_tech_skill in np.arange(len(SS_keywords)):
    SS_Count[i_tech_skill] = data_jobs_df.iloc[:,23+i_tech_skill].sum()

SS_Count
# Out:
# array([261, 151,   0,   5,  23])

# %%
# construct a dataFrame using the SS keywords and SS keyword counSS
df_SS = pd.DataFrame({'SS_Keywords':SS_keywords, 'SSkeywords_Counts':SS_Count})
df_SS.sort_values('SSkeywords_Counts',inplace=True)

# now do a bar chart on desired Technical Skills
plt.figure(figsize=(13,8))
fig,ax = plt.subplots()

ax.barh(df_SS.SS_Keywords, df_SS.SSkeywords_Counts, color='b', alpha=0.5, align="center")

plt.title("Popularity of Desired Soft Skills")
ax.set_xlabel("Number of Job Openings Requiring the Soft Skill")

for i, v in enumerate(df_SS.SSkeywords_Counts):
    ax.text(v + 30, i, str(v), color='black', fontweight='bold')
plt.grid()
plt.tight_layout()
plt.savefig("Bar_Popularity_of_Desired_Soft_Skills.png", bbox_inches='tight')
plt.show()

# %%
# finalized keywords for technical tools:

# Python
# SQL
# JavaScript / Java
# MongoDB
# Hadoop
# Database
# Excel / VBA
# R
# Spark
# Tableau
# D3

# initialize the flag tags
data_jobs_df['SS_Python_flag'] = 0 
data_jobs_df['SS_SQL_flag'] = 0 
data_jobs_df['SS_JavaScript_flag'] = 0 
data_jobs_df['SS_MongoDB_flag'] = 0 
data_jobs_df['SS_Hadoop_flag'] = 0 
data_jobs_df['SS_Database_flag'] = 0 
data_jobs_df['SS_ExcelVBA_flag'] = 0 
data_jobs_df['SS_R_flag'] = 0 
data_jobs_df['SS_Spark_flag'] = 0 
data_jobs_df['SS_Tableau_flag'] = 0 
data_jobs_df['SS_D3_flag'] = 0 

data_jobs_df.head(1)
# Out:
#                                                  Company     job_title  \
# Industry
# Business/Finance/Accounting  North American Savings Bank  Data Analyst
#
#                             Pay Type  High Salary  Low Salary  \
# Industry
# Business/Finance/Accounting   ANNUAL      76361.0     48957.0
#
#                                                                job_description  \
# Industry
# Business/Finance/Accounting  <h3>Job Description</h3><div>North American Sa...
#
#                             Country      City, State  Rating Average  \
# Industry
# Business/Finance/Accounting      US  Kansas City, MO            0.88
#
#                              Number of Ratings  ...  SS_SQL_flag  \
# Industry                                        ...
# Business/Finance/Accounting              14139  ...            0
#
#                              SS_JavaScript_flag  SS_MongoDB_flag  \
# Industry
# Business/Finance/Accounting                   0                0
#
#                              SS_Hadoop_flag  SS_Database_flag  \
# Industry
# Business/Finance/Accounting               0                 0
#
#                              SS_ExcelVBA_flag  SS_R_flag  SS_Spark_flag  \
# Industry
# Business/Finance/Accounting                 0          0              0
#
#                              SS_Tableau_flag  SS_D3_flag
# Industry
# Business/Finance/Accounting                0           0
#
# [1 rows x 43 columns]

# %%
for irow in np.arange(len(data_jobs_df.head(1))):    

    if ("python" in data_jobs_df.job_description[irow]):
        data_jobs_df.head(1).iloc[irow,10] = 1
    
    if ("sql" in data_jobs_df.job_description[irow]) :
        data_jobs_df.head(1).iloc[irow,11] = 1
        
    if ("java" in data_jobs_df.job_description[irow]):
        data_jobs_df.head(1).iloc[irow,12] = 1
        
    if ("mangodb" in data_jobs_df.job_description[irow]) :
        data_jobs_df.head(1).iloc[irow,13] = 1
    
    if ("hadoop" in data_jobs_df.job_description[irow]):
        data_jobs_df.head(1).iloc[irow,14] = 1  
        
    if ("database" in data_jobs_df.job_description[irow]):
        data_jobs_df.head(1).iloc[irow,15] = 1
        
    if (("excel" in data_jobs_df.job_description[irow]) or ("vba" in data_jobs_df.job_description[irow])) :
        data_jobs_df.head(1).iloc[irow,16] = 1
        
    if ((" r " in data_jobs_df.job_description[irow]) or (" r." in data_jobs_df.job_description[irow])\
        or ((" r," in data_jobs_df.job_description[irow]))):
        data_jobs_df.iloc[irow,17] = 1
        
    if ("spark" in data_jobs_df.job_description[irow]) :
        data_jobs_df.iloc[irow,18] = 1
    
    if ("tableau" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,19] = 1  
        
    if ("d3" in data_jobs_df.job_description[irow]):
        data_jobs_df.iloc[irow,20] = 1  
    
TT_keywords = ['Python', 'SQL', 'Java', 'MangoDB','Hadoop','Database','Excel/VBA','R','Spark','Tableau','D3']
TT_Count = np.arange(len(TT_keywords))

for i_tech_tool in np.arange(len(TT_keywords)):
    TT_Count[i_tech_tool] = data_jobs_df.iloc[:,10+i_tech_tool].sum()

print(TT_Count)

# construct a dataFrame using the TT keywords and TT keyword counSS
df_TT = pd.DataFrame({'TT_Keywords':TT_keywords, 'TTkeywords_Counts':TT_Count})
df_TT.sort_values('TTkeywords_Counts',inplace=True)
# Out:
# [219  31   0 152  19 105   3 391  17  43  12]

# %%
# now do a bar chart on desired Technical Skills
plt.figure(figsize=(13,8))
fig,ax = plt.subplots()

ax.barh(df_TT.TT_Keywords, df_TT.TTkeywords_Counts, color='b', alpha=0.5, align="center")

plt.title("Popularity of Desired Technical Tools")
ax.set_xlabel("Number of Job Openings Requiring the Technical Tools")

for i, v in enumerate(df_TT.TTkeywords_Counts):
    ax.text(v + 30, i, str(v), color='black', fontweight='bold')
plt.grid()
plt.tight_layout()
plt.savefig("Bar_Popularity_of_Desired_Technial_Tools.png", bbox_inches='tight')
plt.show()
